# %%
import pandas, copy, json, bz2

from tqdm import tqdm

pandas.options.display.max_columns=999

# %% [markdown]
# # Creating the COGUK dataset
#
# First, let's load in the COGUK metadata file that is publicly available via
#
# `wget https://cog-uk.s3.climb.ac.uk/phylogenetics/latest/cog_metadata.csv
# `
#
# Note that we can infer `cogid` from the `sequence_name` and it is not guaranteed unique, so we shall keep the last.

# %%
cog_metadata=pandas.read_csv('cog_metadata-20210624.csv.gz')

def split_sequence_name(row):
    cols=row['sequence_name'].split('/')
    if len(cols)==3:
        return(cols[1])
    else:
        return(None)

# rename the country to avoid a conflict with the ENA dataset later
cog_metadata.rename(columns={'country':'cog_country'},inplace=True)

# infer the cogid
cog_metadata['cogid']=cog_metadata.apply(split_sequence_name,axis=1)        

# set as the index and de-duplicate
cog_metadata.set_index('cogid',inplace=True,verify_integrity=False)
cog_metadata=cog_metadata.loc[~cog_metadata.index.duplicated(keep='first')]
cog_metadata.reset_index(inplace=True)
cog_metadata.set_index('cogid',inplace=True,verify_integrity=True)

print("There are "+str(len(cog_metadata))+" rows in the dataset")

cog_metadata[:3]
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# There are 506543 rows in the dataset
#                                      sequence_name cog_country    adm1  \
# cogid
# PHEC-L307LF63  Northern_Ireland/PHEC-L307LF63/2021          UK  UK-NIR
# PHEC-L307LF81  Northern_Ireland/PHEC-L307LF81/2021          UK  UK-NIR
# PHEC-L307LF45  Northern_Ireland/PHEC-L307LF45/2021          UK  UK-NIR
#
#               is_pillar_2 sample_date  epi_week    lineage lineages_version  \
# cogid
# PHEC-L307LF63           N  2021-06-15        77  B.1.617.2   PLEARN-v1.2.13
# PHEC-L307LF81           N  2021-06-15        77  B.1.617.2   PLEARN-v1.2.13
# PHEC-L307LF45           N  2021-06-15        77  B.1.617.2   PLEARN-v1.2.13
#
#                lineage_conflict  lineage_ambiguity_score  \
# cogid
# PHEC-L307LF63               NaN                      NaN
# PHEC-L307LF81               NaN                      NaN
# PHEC-L307LF45               NaN                      NaN
#
#                          scorpio_call  scorpio_support  scorpio_conflict  \
# cogid
# PHEC-L307LF63  Delta (B.1.617.2-like)              1.0               0.0
# PHEC-L307LF81  Delta (B.1.617.2-like)              1.0               0.0
# PHEC-L307LF45  Delta (B.1.617.2-like)              1.0               0.0
#
#               t1001i n501y d614g del_21765_6 y453f del_1605_3 a222v n439k  \
# cogid
# PHEC-L307LF63      T     N     G         ref     Y        ref     A     N
# PHEC-L307LF81      T     N     G         ref     Y        ref     A     N
# PHEC-L307LF45      T     N     G         ref     Y        ref     A     N
#
#                                                        mutations p681h  \
# cogid
# PHEC-L307LF63  synSNP:G1186C|synSNP:C3037T|orf1ab:A1306S|orf1...     R
# PHEC-L307LF81  synSNP:C3037T|orf1ab:A1306S|orf1ab:P2046L|orf1...     R
# PHEC-L307LF45  orf1ab:P309L|synSNP:C1267T|synSNP:C3037T|orf1a...     R
#
#               q27stop e484k p323l
# cogid
# PHEC-L307LF63       Q     E     L
# PHEC-L307LF81       Q     E     L
# PHEC-L307LF45       Q     E     L

# %% [markdown]
# But we don't have the ENA `run_accession` which we need to link to the FASTQ files in object store, nor do we know what the sequencing platform was, which we need to choose the right flow in SP3, so let's load in a list from the ENA and again we can infer `cogid` from the `submitted_ftp` file.

# %% [markdown]
# To get the latest TSV issue the below in a terminal; be warned that unless you subset the fields it will be >2GB; either way best to compress.
#
# `curl "https://www.ebi.ac.uk/ena/portal/api/filereport?accession=PRJEB37886&result=read_run&fields=study_accession,sample_accession,secondary_sample_accession,experiment_accession,run_accession,instrument_platform,country,submitted_ftp,read_count,base_count&limit=1000000&format=tsv&download=true" > cog-ena-20210624.tsv`

# %%
ena_sample=pandas.read_csv('ena_samples_all_fields.tsv',sep='\t')
ena_sample[:2]
# Out:
#   study_accession secondary_study_accession sample_accession  \
# 0      PRJEB37886                 ERP121228     SAMEA6791711
# 1      PRJEB37886                 ERP121228     SAMEA6791712
#
#   secondary_sample_accession experiment_accession run_accession  \
# 0                 ERS4519383           ERX4078237    ERR4082025
# 1                 ERS4519384           ERX4078238    ERR4082026
#
#   submission_accession   tax_id  \
# 0           ERA2524107  2697049
# 1           ERA2524109  2697049
#
#                                    scientific_name instrument_platform  \
# 0  Severe acute respiratory syndrome coronavirus 2     OXFORD_NANOPORE
# 1  Severe acute respiratory syndrome coronavirus 2     OXFORD_NANOPORE
#
#   instrument_model  library_name library_layout  nominal_length  \
# 0           MinION           NaN         SINGLE             NaN
# 1           MinION           NaN         SINGLE             NaN
#
#   library_strategy library_source library_selection  read_count  base_count  \
# 0         AMPLICON      VIRAL RNA               PCR      211388   103672824
# 1         AMPLICON      VIRAL RNA               PCR      427553   210103657
#
#                center_name first_public last_updated  \
# 0  University of Cambridge   2020-04-29   2020-04-29
# 1  University of Cambridge   2020-04-29   2020-04-29
#
#                                     experiment_title  \
# 0  MinION sequencing; COG-UK/CAMB-7374F/CAMB:2020...
# 1  MinION sequencing; COG-UK/CAMB-7375E/CAMB:2020...
#
#                                 study_title  \
# 0  COVID-19 Genomics UK (COG-UK) consortium
# 1  COVID-19 Genomics UK (COG-UK) consortium
#
#                                          study_alias  \
# 0  ena-STUDY-COVID-19 Genomics UK Consortium-18-0...
# 1  ena-STUDY-COVID-19 Genomics UK Consortium-18-0...
#
#                                     experiment_alias  \
# 0  COG-UK/CAMB-7374F/CAMB:20200404_1455_MN30591_F...
# 1  COG-UK/CAMB-7375E/CAMB:20200404_1455_MN30591_F...
#
#                                            run_alias  fastq_bytes  \
# 0  COG-UK/CAMB-7374F/CAMB:20200404_1455_MN30591_F...     91988098
# 1  COG-UK/CAMB-7375E/CAMB:20200404_1455_MN30591_F...    186032909
#
#                           fastq_md5  \
# 0  28d6f7213833a6e5025fb4d42767e011
# 1  811cf092a7ea2ac765211fc38e6b5c74
#
#                                            fastq_ftp  \
# 0  ftp.sra.ebi.ac.uk/vol1/fastq/ERR408/005/ERR408...
# 1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR408/006/ERR408...
#
#                                         fastq_aspera  \
# 0  fasp.sra.ebi.ac.uk:/vol1/fastq/ERR408/005/ERR4...
# 1  fasp.sra.ebi.ac.uk:/vol1/fastq/ERR408/006/ERR4...
#
#                                         fastq_galaxy  submitted_bytes  \
# 0  ftp.sra.ebi.ac.uk/vol1/fastq/ERR408/005/ERR408...        108722728
# 1  ftp.sra.ebi.ac.uk/vol1/fastq/ERR408/006/ERR408...        220151623
#
#                       submitted_md5  \
# 0  18f53e799c25060ad74ae240c253f3a8
# 1  39d9f40115d2a4b63503efc40ed12906
#
#                                        submitted_ftp  \
# 0  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082025/C...
# 1  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082026/C...
#
#                                     submitted_aspera  \
# 0  fasp.sra.ebi.ac.uk:/vol1/run/ERR408/ERR4082025...
# 1  fasp.sra.ebi.ac.uk:/vol1/run/ERR408/ERR4082026...
#
#                                     submitted_galaxy submitted_format  \
# 0  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082025/C...              BAM
# 1  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082026/C...              BAM
#
#    sra_bytes  sra_md5  sra_ftp  sra_aspera  sra_galaxy  cram_index_ftp  \
# 0        NaN      NaN      NaN         NaN         NaN             NaN
# 1        NaN      NaN      NaN         NaN         NaN             NaN
#
#    cram_index_aspera  cram_index_galaxy       sample_alias  \
# 0                NaN                NaN  COG-UK/CAMB-7374F
# 1                NaN                NaN  COG-UK/CAMB-7375E
#
#                        broker_name  nominal_sdev first_created  \
# 0  COVID-19 Genomics UK Consortium           NaN    2020-04-29
# 1  COVID-19 Genomics UK Consortium           NaN    2020-04-29
#
#   sample_description parent_study sample_accession.1     accession  \
# 0  COG-UK/CAMB-7374F   PRJEB39908       SAMEA6791711  SAMEA6791711
# 1  COG-UK/CAMB-7375E   PRJEB39908       SAMEA6791712  SAMEA6791712
#
#   secondary_sample_accession.1  bio_material  cell_line  cell_type  \
# 0                   ERS4519383           NaN        NaN        NaN
# 1                   ERS4519384           NaN        NaN        NaN
#
#    collected_by  collection_date  country  cultivar  culture_collection  \
# 0           NaN              NaN      NaN       NaN                 NaN
# 1           NaN              NaN      NaN       NaN                 NaN
#
#                                          description  dev_stage  ecotype  \
# 0  MinION sequencing; COG-UK/CAMB-7374F/CAMB:2020...        NaN      NaN
# 1  MinION sequencing; COG-UK/CAMB-7375E/CAMB:2020...        NaN      NaN
#
#    environmental_sample first_public.1  germline  identified_by  isolate  \
# 0                 False     2020-04-29     False            NaN      NaN
# 1                 False     2020-04-29     False            NaN      NaN
#
#    isolation_source  location  mating_type  serotype  serovar  sex  \
# 0               NaN       NaN          NaN       NaN      NaN  NaN
# 1               NaN       NaN          NaN       NaN      NaN  NaN
#
#    submitted_sex  specimen_voucher  strain  sub_species  sub_strain  \
# 0            NaN               NaN     NaN          NaN         NaN
# 1            NaN               NaN     NaN          NaN         NaN
#
#    tissue_lib  tissue_type  variety  tax_id.1  \
# 0         NaN          NaN      NaN   2697049
# 1         NaN          NaN      NaN   2697049
#
#                                  scientific_name.1     sample_alias.1  \
# 0  Severe acute respiratory syndrome coronavirus 2  COG-UK/CAMB-7374F
# 1  Severe acute respiratory syndrome coronavirus 2  COG-UK/CAMB-7375E
#
#    checklist            center_name.1  depth  elevation  altitude  \
# 0  ERC000011  University of Cambridge    NaN        NaN       NaN
# 1  ERC000011  University of Cambridge    NaN        NaN       NaN
#
#    environment_biome  environment_feature  environment_material  temperature  \
# 0                NaN                  NaN                   NaN          NaN
# 1                NaN                  NaN                   NaN          NaN
#
#    salinity  sampling_campaign  sampling_site  sampling_platform  \
# 0       NaN                NaN            NaN                NaN
# 1       NaN                NaN            NaN                NaN
#
#    protocol_label  project_name  host  host_tax_id  host_status  host_sex  \
# 0             NaN           NaN   NaN          NaN          NaN       NaN
# 1             NaN           NaN   NaN          NaN          NaN       NaN
#
#    submitted_host_sex  host_body_site  host_gravidity  host_phenotype  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
#
#    host_genotype  host_growth_conditions  environmental_package  \
# 0            NaN                     NaN                    NaN
# 1            NaN                     NaN                    NaN
#
#    investigation_type  experimental_factor  sample_collection  \
# 0                 NaN                  NaN                NaN
# 1                 NaN                  NaN                NaN
#
#    sequencing_method  target_gene  ph                    broker_name.1  \
# 0                NaN          NaN NaN  COVID-19 Genomics UK Consortium
# 1                NaN          NaN NaN  COVID-19 Genomics UK Consortium
#
#         sample_title  sample_material  taxonomic_identity_marker  \
# 0  COG-UK/CAMB-7374F              NaN                        NaN
# 1  COG-UK/CAMB-7375E              NaN                        NaN
#
#    assembly_quality  assembly_software  taxonomic_classification  \
# 0               NaN                NaN                       NaN
# 1               NaN                NaN                       NaN
#
#    completeness_score  contamination_score  binning_software  lat  lon  \
# 0                 NaN                  NaN               NaN  NaN  NaN
# 1                 NaN                  NaN               NaN  NaN  NaN
#
#    sample_capture_status  collection_date_submitted  submission_tool
# 0                    NaN                        NaN              NaN
# 1                    NaN                        NaN              NaN

# %%
cog_ena=pandas.read_csv('cog_ena-20210624.tsv.gz',sep='\t')

def create_cogid(row):
    if isinstance(row['submitted_ftp'],str):
        return(row['submitted_ftp'].split('/')[-1].split('.')[0])
    else:
        return(None)

# rename the country to avoid a conflict with the metadata dataset later
cog_ena.rename(columns={'country':'ena_country'},inplace=True)

# filter down to Illumina and ONT only (excludes Ion Torrent)
cog_ena=cog_ena.loc[cog_ena.instrument_platform.isin(['ILLUMINA','OXFORD_NANOPORE'])]

# infer the cogid
cog_ena['cogid']=cog_ena.apply(create_cogid,axis=1)

# remove any samples with no cogid
cog_ena=cog_ena.loc[cog_ena.cogid.notna()]

# set as the index and de-duplicate
cog_ena.set_index('cogid',inplace=True,verify_integrity=False)
cog_ena=cog_ena.loc[~cog_ena.index.duplicated(keep='first')]
cog_ena.reset_index(inplace=True)
cog_ena.set_index('cogid',inplace=True,verify_integrity=True)

print("There are "+str(len(cog_ena))+" rows in the dataset")

cog_ena[:3]
# Out:
# There are 496763 rows in the dataset
#            study_accession sample_accession secondary_sample_accession  \
# cogid
# CAMB-7374F      PRJEB37886     SAMEA6791711                 ERS4519383
# CAMB-7375E      PRJEB37886     SAMEA6791712                 ERS4519384
# CAMB-7376D      PRJEB37886     SAMEA6791713                 ERS4519385
#
#            experiment_accession run_accession instrument_platform ena_country  \
# cogid
# CAMB-7374F           ERX4078237    ERR4082025     OXFORD_NANOPORE         NaN
# CAMB-7375E           ERX4078238    ERR4082026     OXFORD_NANOPORE         NaN
# CAMB-7376D           ERX4078239    ERR4082027     OXFORD_NANOPORE         NaN
#
#                                                 submitted_ftp  read_count  \
# cogid
# CAMB-7374F  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082025/C...    211388.0
# CAMB-7375E  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082026/C...    427553.0
# CAMB-7376D  ftp.sra.ebi.ac.uk/vol1/run/ERR408/ERR4082027/C...    374754.0
#
#              base_count
# cogid
# CAMB-7374F  103672824.0
# CAMB-7375E  210103657.0
# CAMB-7376D  183823695.0

# %% [markdown]
# Now let's do an inner join so every row has a unique `cogid` and an ENA `run_accession`

# %%
cog=cog_metadata.join(cog_ena,how='inner')

# %%
print("This gives us "+str(len(cog))+" COGUK samples with an ENA accession number")

print("There are " +str(len(cog.loc[cog.lineage.isna()]))+" samples with no PANGO lineage and " +str(len(cog.loc[cog.scorpio_call.isna()]))+ " samples with no SCORPIO lineage")
# Out:
# This gives us 455352 COGUK samples with an ENA accession number
# There are 0 samples with no PANGO lineage and 169437 samples with no SCORPIO lineage

# %% [markdown]
# Now let's match to what is in the `ena` bucket on object store so we can make sure we are only asking for run accessions that have fastq files in the bucket.

# %%
with bz2.open('oci-ena-bucket-20210625.json.bz2') as jsonFile:
    jsonObject = json.load(jsonFile)
    jsonFile.close()
    
jsonPayload=jsonObject['data']

# %%
ena_accessions=set()

for i in tqdm(jsonPayload):
    
    fastaFile=i['name']
    
    if "_" in fastaFile:
        era=fastaFile.split('_')[0]
    else:
        era=fastaFile.split('.')[0]
    if era not in ena_accessions:
        ena_accessions.add(era)

print("There are "+str(len(ena_accessions))+" unique ENA run accessions stored in the ena bucket in object store")
# Out:
# 100%|██████████| 764990/764990 [00:00<00:00, 812165.37it/s]
# There are 308136 unique ENA run accessions stored in the ena bucket in object store

# %%
cog['in_ena_bucket']=cog.run_accession.isin(ena_accessions)
cog.in_ena_bucket.value_counts()
# Out:
# True     228773
# False    226579
# Name: in_ena_bucket, dtype: int64

# %%
cog.to_csv('cog_dataset-20210624.csv.gz')
